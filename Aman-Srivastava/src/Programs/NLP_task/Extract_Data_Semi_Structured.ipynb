# %%
import easyocr
import cv2

# %%
from PIL import Image

# %%
image_file = Image.open("tabular_data.png")
image_file
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2242x2988 at 0x7F7C1635C8B0>

# %%
image = cv2.imread('tabular_data.png')

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result = reader.readtext("tabular_data.png", detail = 0, paragraph=False)

# %%
text_data = ""
for item in result:
    text_data += item

# %%
text_data.split()
# Out:
# ['TSCMMSZ5221BS',
#  'THRU',
#  'MMSZ5259BS52OOmW',
#  'Surface',
#  'Mount',
#  'Zener',
#  'DiodeVoltage',
#  'Range40.39Volts200m',
#  'Watts',
#  'Rower',
#  'Dissipation:SOD-323Features0.018/0.25}Typ',
#  'Min_Planar',
#  'die',
#  'construction3.837(0.85)Max200',
#  'mW',
#  'power',
#  'dissipationIdeally',
#  'suited',
#  'for',
#  'automated',
#  'assemblyprocessesGeneral',
#  'purpose,',
#  'medium',
#  'currentStandard',
#  'zener',
#  'voltage',
#  'tolerance',
#  'is',
#  '+5%0.13502.78)0.0771.95)0i7(2',
#  '38)3.363/1.76)Plastic',
#  'MaterialUL',
#  'recognition',
#  'flammabilityclassification',
#  '94V-08.012(0.30)Min_Mechanical',
#  'DataCase:',
#  'SOD-323,',
#  'Plastic.002{0J.nJ5}0.053{".35}Typ.',
#  'Mir_0.0453.Terminals:',
#  'Solderable',
#  'per',
#  'MIIL-STD-202,Method',
#  '208Polarity:',
#  'Cathode',
#  'bandMarking:',
#  'Date',
#  'Code',
#  'and',
#  'Type',
#  'Code8.814(8.10)MaxType',
#  'Code:',
#  'See',
#  'table',
#  'on',
#  'Page',
# ...

# %%
data=re.sub('[^a-zA-Z]', ' ', str(text_data))
data=re.sub(' +', ' ', data)
data=re.sub(r'\b(ha)+\b', '', data)
data=data.replace('\n', ' ')
data = data.lower().strip()
data
# Out:
# 'tscmmsz bs thru mmsz bs oomw surface mount zener diodevoltage range volts m watts rower dissipation sod features typ min planar die construction max mw power dissipationideally suited for automated assemblyprocessesgeneral purpose medium currentstandard zener voltage tolerance is i plastic materialul recognition flammabilityclassification v min mechanical datacase sod plastic j nj typ mir terminals solderable per miil std method polarity cathode bandmarking date code and type code maxtype code see table on page weight grams approx dimensions in inches and millimeters maximum ratings and electrical characteristicsirating at cambient temperature unless otherwise specified maximum ratingstype numbersymbolvalueunitsforward voltageif omavf vpower dissipation note pd mwthermal resistance junction t ambient air note re ja operating and storage temperature rangetj t note valid provided that device terminals are kept at ambient temperature c mtstg'

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/knoldus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/knoldus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = set(stopwords.words('english'))

# %%
tokens = word_tokenize(data)
tokens
# Out:
# ['tscmmsz',
#  'bs',
#  'thru',
#  'mmsz',
#  'bs',
#  'oomw',
#  'surface',
#  'mount',
#  'zener',
#  'diodevoltage',
#  'range',
#  'volts',
#  'm',
#  'watts',
#  'rower',
#  'dissipation',
#  'sod',
#  'features',
#  'typ',
#  'min',
#  'planar',
#  'die',
#  'construction',
#  'max',
#  'mw',
#  'power',
#  'dissipationideally',
#  'suited',
#  'for',
#  'automated',
#  'assemblyprocessesgeneral',
#  'purpose',
#  'medium',
#  'currentstandard',
#  'zener',
#  'voltage',
#  'tolerance',
#  'is',
#  'i',
#  'plastic',
#  'materialul',
#  'recognition',
#  'flammabilityclassification',
#  'v',
#  'min',
#  'mechanical',
#  'datacase',
#  'sod',
#  'plastic',
#  'j',
#  'nj',
#  'typ',
#  'mir',
#  'terminals',
#  'solderable',
#  'per',
#  'miil',
#  'std',
#  'method',
#  'polarity',
#  'cathode',
#  'bandmarking',
#  'date',
#  'code',
#  'and',
#  'type',
#  'code',
#  'maxtype',
#  'code',
#  'see',
#  'table',
#  'on',
#  'page',
#  'weight',
#  'grams',
#  'approx',
# ...

# %%
filtered_tokens = [word for word in tokens if word.lower() not in stopwords]

# %%
filtered_tokens
# Out:
# ['tscmmsz',
#  'bs',
#  'thru',
#  'mmsz',
#  'bs',
#  'oomw',
#  'surface',
#  'mount',
#  'zener',
#  'diodevoltage',
#  'range',
#  'volts',
#  'watts',
#  'rower',
#  'dissipation',
#  'sod',
#  'features',
#  'typ',
#  'min',
#  'planar',
#  'die',
#  'construction',
#  'max',
#  'mw',
#  'power',
#  'dissipationideally',
#  'suited',
#  'automated',
#  'assemblyprocessesgeneral',
#  'purpose',
#  'medium',
#  'currentstandard',
#  'zener',
#  'voltage',
#  'tolerance',
#  'plastic',
#  'materialul',
#  'recognition',
#  'flammabilityclassification',
#  'v',
#  'min',
#  'mechanical',
#  'datacase',
#  'sod',
#  'plastic',
#  'j',
#  'nj',
#  'typ',
#  'mir',
#  'terminals',
#  'solderable',
#  'per',
#  'miil',
#  'std',
#  'method',
#  'polarity',
#  'cathode',
#  'bandmarking',
#  'date',
#  'code',
#  'type',
#  'code',
#  'maxtype',
#  'code',
#  'see',
#  'table',
#  'page',
#  'weight',
#  'grams',
#  'approx',
#  'dimensions',
#  'inches',
#  'millimeters',
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/knoldus/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
tagged_tokens = nltk.pos_tag(filtered_tokens)

# %%
tagged_tokens
# Out:
# [('tscmmsz', 'NN'),
#  ('bs', 'NN'),
#  ('thru', 'NN'),
#  ('mmsz', 'NN'),
#  ('bs', 'NN'),
#  ('oomw', 'JJ'),
#  ('surface', 'NN'),
#  ('mount', 'NN'),
#  ('zener', 'NN'),
#  ('diodevoltage', 'NN'),
#  ('range', 'NN'),
#  ('volts', 'NNS'),
#  ('watts', 'VBP'),
#  ('rower', 'JJR'),
#  ('dissipation', 'NN'),
#  ('sod', 'NN'),
#  ('features', 'NNS'),
#  ('typ', 'VBP'),
#  ('min', 'JJ'),
#  ('planar', 'NN'),
#  ('die', 'NN'),
#  ('construction', 'NN'),
#  ('max', 'NN'),
#  ('mw', 'NN'),
#  ('power', 'NN'),
#  ('dissipationideally', 'RB'),
#  ('suited', 'VBN'),
#  ('automated', 'JJ'),
#  ('assemblyprocessesgeneral', 'JJ'),
#  ('purpose', 'NN'),
#  ('medium', 'NN'),
#  ('currentstandard', 'NN'),
#  ('zener', 'NN'),
#  ('voltage', 'NN'),
#  ('tolerance', 'NN'),
#  ('plastic', 'NN'),
#  ('materialul', 'NN'),
#  ('recognition', 'NN'),
#  ('flammabilityclassification', 'NN'),
#  ('v', 'IN'),
#  ('min', 'JJ'),
#  ('mechanical', 'JJ'),
#  ('datacase', 'NN'),
#  ('sod', 'NN'),
# ...

# %%
for word, tag in tagged_tokens:
    print(word, tag)
# Out:
# tscmmsz NN
# bs NN
# thru NN
# mmsz NN
# bs NN
# oomw JJ
# surface NN
# mount NN
# zener NN
# diodevoltage NN
# range NN
# volts NNS
# watts VBP
# rower JJR
# dissipation NN
# sod NN
# features NNS
# typ VBP
# min JJ
# planar NN
# die NN
# construction NN
# max NN
# mw NN
# power NN
# dissipationideally RB
# suited VBN
# automated JJ
# assemblyprocessesgeneral JJ
# purpose NN
# medium NN
# currentstandard NN
# zener NN
# voltage NN
# tolerance NN
# plastic NN
# materialul NN
# recognition NN
# flammabilityclassification NN
# v IN
# min JJ
# mechanical JJ
# datacase NN
# sod NN
# plastic NN
# j NN
# nj JJ
# typ NN
# mir NN
# terminals NNS
# solderable JJ
# per IN
# miil NN
# std NN
# method NN
# polarity NN
# cathode NN
# bandmarking VBG
# date NN
# code NN
# type NN
# code NN
# maxtype NN
# code NN
# see VBP
# table JJ
# page NN
# weight VBD
# grams NNS
# approx JJ
# dimensions NNS
# inches NNS
# millimeters NNS
# maximum JJ
# ratings NNS
# electrical JJ
# characteristicsirating VBG
# ...

# %%
entities = nltk.ne_chunk(tagged_tokens)

# %%
entities
# Out:
# Tree('S', [('tscmmsz', 'NN'), ('bs', 'NN'), ('thru', 'NN'), ('mmsz', 'NN'), ('bs', 'NN'), ('oomw', 'JJ'), ('surface', 'NN'), ('mount', 'NN'), ('zener', 'NN'), ('diodevoltage', 'NN'), ('range', 'NN'), ('volts', 'NNS'), ('watts', 'VBP'), ('rower', 'JJR'), ('dissipation', 'NN'), ('sod', 'NN'), ('features', 'NNS'), ('typ', 'VBP'), ('min', 'JJ'), ('planar', 'NN'), ('die', 'NN'), ('construction', 'NN'), ('max', 'NN'), ('mw', 'NN'), ('power', 'NN'), ('dissipationideally', 'RB'), ('suited', 'VBN'), ('automated', 'JJ'), ('assemblyprocessesgeneral', 'JJ'), ('purpose', 'NN'), ('medium', 'NN'), ('currentstandard', 'NN'), ('zener', 'NN'), ('voltage', 'NN'), ('tolerance', 'NN'), ('plastic', 'NN'), ('materialul', 'NN'), ('recognition', 'NN'), ('flammabilityclassification', 'NN'), ('v', 'IN'), ('min', 'JJ'), ('mechanical', 'JJ'), ('datacase', 'NN'), ('sod', 'NN'), ('plastic', 'NN'), ('j', 'NN'), ('nj', 'JJ'), ('typ', 'NN'), ('mir', 'NN'), ('terminals', 'NNS'), ('solderable', 'JJ'), ('per', 'IN'), ('
# ...
